# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulrahman0700/intern_FlyRank_ai/blob/main/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abdulrahman0700/intern_FlyRank_ai/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
"""
Ranking Signal Analysis —
I'm choosing this because before FlyRank commits to scoring or clustering pages,
someone needs to establish which observable signals are actually associated with movement in the first place.
This lane produces the evidence base the other lanes assume.
"""
# Out:
# " \nRanking Signal Analysis — \nI'm choosing this because before FlyRank commits to scoring or clustering pages,\nsomeone needs to establish which observable signals are actually associated with movement in the first place.\nThis lane produces the evidence base the other lanes assume.\n"

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Decision: Which observable signals a content strategist should trust when
# deciding why a page's performance is weak, before committing edit time.
# Who acts on it: A content strategist with limited weekly review capacity.
# Cost of a wrong call: Editorial hours spent "fixing" a signal that doesn't
# actually move visibility or clicks, plus eroded trust in future recommendations.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

data = pd.read_csv("/content/content_refresh_anonymized.csv")

print(data.shape)
print(data.columns.tolist())
print("********")
print(data['trend_direction'].value_counts())
print((data['impressions_90d'] >= 500).sum())

data.groupby('trend_direction')['avg_position'].median()
# Out:
# (30000, 44)
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
# ********
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
# 16726
# trend_direction
# down      11.3
# flat       6.6
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
"""
Observed:
In the analyzed sample, pages tagged "down" (declining) have a lower — i.e.
better — median search position (11.3) than pages tagged "up" (rising, 15.3).
Stable and down-trending pages sit at nearly the same median position
(11.4 vs 11.3), while flat pages sit noticeably higher (better) at 6.6.

Measured:
The gap between down-trending and up-trending pages is 4.0 median position
points (11.3 vs 15.3) in this sample of 30,000 starter rows, of which
16,726 pages (about 56%) carry at least 500 impressions in the last 90
days — enough volume that this isn't just noise from low-traffic pages.
[A formal correlation or group-comparison test between avg_position and
trend_direction is still needed before this becomes a claim I'd stand
behind — median gap alone is descriptive, not yet a tested effect size.]

Directional:
This suggests that "declining" pages are not simply weak pages overall —
some are declining from genuinely strong positions. That distinction may
be worth prioritizing when triaging which pages deserve review, though
it doesn't by itself explain why a well-positioned page would be losing
traffic.

Decision-support:
This ranks candidates for a reviewer to check first — it does not tell
you the reviewer will be right, only that these are the most
evidence-backed places to look.

Never causal:
"X caused Y" / "adding X will improve Y."
Lane 1 is observational — correlation and association only. The guide is
explicit: proving causation would require an actual experiment (A/B test,
before/after intervention with controls), which this data alone cannot
give you. If a strategist changes a page based on my finding and traffic
later improves, I can't claim my analysis caused that improvement.

Never "predicting Google":
"This signal is a ranking factor" / "this predicts how Google's algorithm
scores pages."
I'm only working with FlyRank's own observed search/analytics signals
(impressions, clicks, position, sessions) — never Google's internal
algorithm, and never their AI citation/ranking logic. Any pattern I find
is a pattern in this data, not a discovered rule of how Google works.
"""
# Out:
# '\nObserved:\nIn the analyzed sample, pages tagged "down" (declining) have a lower — i.e.\nbetter — median search position (11.3) than pages tagged "up" (rising, 15.3).\nStable and down-trending pages sit at nearly the same median position\n(11.4 vs 11.3), while flat pages sit noticeably higher (better) at 6.6.\n\nMeasured:\nThe gap between down-trending and up-trending pages is 4.0 median position\npoints (11.3 vs 15.3) in this sample of 30,000 starter rows, of which\n16,726 pages (about 56%) carry at least 500 impressions in the last 90\ndays — enough volume that this isn\'t just noise from low-traffic pages.\n[A formal correlation or group-comparison test between avg_position and\ntrend_direction is still needed before this becomes a claim I\'d stand\nbehind — median gap alone is descriptive, not yet a tested effect size.]\n\nDirectional:\nThis suggests that "declining" pages are not simply weak pages overall —\nsome are declining from genuinely strong positions. That distinction 
# ...

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
