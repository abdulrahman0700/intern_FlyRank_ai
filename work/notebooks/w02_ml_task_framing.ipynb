# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulrahman0700/intern_FlyRank_ai/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abdulrahman0700/intern_FlyRank_ai/blob/main/work/notebooks/w02_ml_task_framing.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
"""
My lane as an ML task : Ranking
Because we need to order a set of items by relevance or preference
"""
# Out:
# '\nMy lane as an ML task : Ranking\nBecause we need to order a set of items by relevance or preference\n'

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
"""
1) we would predict a relvant order about items
2) The data is already labeled
3) Up & Down in padg Trending

"""
# Out:
# '\n1) we would predict a relvant order about items\n2) The data is already labeled\n3) Up & Down in padg Trending\n\n'

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
"""
Metric : NDCG (Normalized Discounted Cumulative Gain)
ranges from 0 to 1, where 1 means your ranking is perfect and from 0.7 - 0.9 mean Good
"""
# Out:
# '\nMetric : NDCG (Normalized Discounted Cumulative Gain)\nranges from 0 to 1, where 1 means your ranking is perfect and from 0.7 - 0.9 mean Good\n'

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd
data = pd.read_csv('/content/content_refresh_anonymized.csv')
data.sample()
# Out:
#                  content_id          client_id  search_volume  competition  \
# 18871  content_aeb3c0da92cc  client_8527a891e2            0.0          0.0
#
#       competition_level  cpc     content_type    main_intent  word_count  \
# 18871               LOW  0.0  keyword article  informational      1457.0
#
#        char_count  ... char_count_tier  ctr  avg_position  engagement_rate  \
# 18871      9330.0  ...      8000-15000  0.3          11.2              0.0
#
#        scroll_rate  ai_traffic_pct  impression_tier  position_tier  \
# 18871          0.0             0.0         moderate       striking
#
#        trend_direction  trend_pct
# 18871             down      -65.1
#
# [1 rows x 44 columns]

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
"""
The relationship isn't a clean threshold.
An if-statement needs something like if avg_position > 12: flag_as_down.
But your data shows down-trending and stable pages sitting at almost the same position (11.3 vs 11.4) — there's no position value that cleanly separates "declining" from "holding steady."
Any single cutoff you pick will misclassify a large chunk of one group or the other.
"""
# Out:
# '\nThe relationship isn\'t a clean threshold. \nAn if-statement needs something like if avg_position > 12: flag_as_down.\nBut your data shows down-trending and stable pages sitting at almost the same position (11.3 vs 11.4) — there\'s no position value that cleanly separates "declining" from "holding steady."\nAny single cutoff you pick will misclassify a large chunk of one group or the other.\n'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
